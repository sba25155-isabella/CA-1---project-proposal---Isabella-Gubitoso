# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('student_data.csv')

# %%
df.head(5)
# Out:
#   Marital status  Application mode  Application order  Course  \
# 0              1                17                  5   171.0
# 1              1                15                  1  9254.0
# 2              1                 1                  5  9070.0
# 3              1                17                  2  9773.0
# 4              2                39                  1  8014.0
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# The first five rows of the dataset show the structure and the format of the data. This data contains a mixture of categorical and continuous features, such as Marital status, Application Mode, Application Order and course, as columns.
#
# The continuous features are Previous qualification (grade), Admission grade, Unemployment rate, Inflation rate and GDP.
#
# The categorical features are the majority of them. These include demographic information, such as Merital Status, Nacionality, Mother's qualification; course information, such as Application Mode, Applications order, Course and Daytime/evening attendance; and other categorical features.

# %%
df.shape
# Out:
# (4424, 37)

# %% [markdown]
# The dataset contains 4424 obeservations (rows) and 37 attributes (columns).

# %%
df.describe()
# Out:
#        Application mode  Application order       Course  \
# count       4424.000000        4424.000000  4423.000000
# mean          18.669078           1.727848  8856.458738
# std           17.484682           1.313793  2063.763479
# min            1.000000           0.000000    33.000000
# 25%            1.000000           1.000000  9085.000000
# 50%           17.000000           1.000000  9238.000000
# 75%           39.000000           2.000000  9556.000000
# max           57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance  Previous qualification  \
# count                 4424.000000             4424.000000
# mean                     0.890823                4.577758
# std                      0.311897               10.216592
# min                      0.000000                1.000000
# 25%                      1.000000                1.000000
# 50%                      1.000000                1.000000
# ...

# %% [markdown]
# The descriptive statistics reveal important patterns in numerical features.
#
# By compering the mean and the median, we can assess weather the data is symmetrically distributed or contains outliers. When the median and mediun are similar, this means the data is normally distributed. However, when differ significantly, it suggest the presence of outilers.

# %%
df.describe(include=object)
# Out:
#        Marital status Displaced Tuition fees up to date Age at enrollment  \
# count            4424      4424                    4423              4424
# unique              7         3                       3                47
# top                 1         1                       1                18
# freq             3918      2425                    3895              1036
#
#        Curricular units 1st sem (credited)    Target
# count                                 4424      4424
# unique                                  22         7
# top                                      0  Graduate
# freq                                  3847      2207

# %% [markdown]
# This output reveals data about columns stored as text.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   object
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4423 non-null   float64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            1
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            1
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   1
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            1
# Tuition fees up to date                           1
# Gender                                            0
# ...
